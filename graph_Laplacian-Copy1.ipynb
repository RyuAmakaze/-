# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
import math

files = glob.glob("*.csv")
for file in files:  
    print(file)
    data_set = np.loadtxt(
    fname=file, #読み込むファイルのパスと名前
    dtype="float", #floatで読み込む
    delimiter=",", #csvなのでカンマで区切る
    encoding='utf-8',
    skiprows = 1
    )
    
    z = 0
    y = 0
    for data in data_set:
        plt.scatter(data[0], math.sqrt(data[1]*y)/(y+data[1]))
        y = data[1]
        
    plt.title(file) #タイトル
    plt.xlabel("z") #x軸のラベル
    plt.ylabel("Max Grip_Laplacian Variance") #y軸のラベル
    plt.grid() #グリッド線を引く(引かなくてもいい別に)

    plt.show()
# Out:
# OCM喀痰1_濃い背景悪_grid_laplacian.csv
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 21888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 30192 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 28611 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 12356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 32972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26223 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 24746 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 21888 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 30192 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 28611 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 12356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 32972 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26223 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 24746 missing from current font.
#   font.set_text(s, 0, flags=flags)
# OCM喀痰1_濃い背景良_grid_laplacian.csv
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 33391 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 33391 missing from current font.
#   font.set_text(s, 0, flags=flags)
# OCM喀痰2_薄い背景悪[抜け２枚]_grid_laplacian.csv
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 25244 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 12369 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 65298 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26522 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 34180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 25244 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 12369 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 65298 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26522 missing from current font.
#   font.set_text(s, 0, flags=flags)
# OCM喀痰4_普通背景良_grid_laplacian.csv
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 26222 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 36890 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 26222 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 36890 missing from current font.
#   font.set_text(s, 0, flags=flags)
# OCM喀痰4_薄い背景悪_grid_laplacian.csv
# OCM喀痰5_薄い背景良_grid_laplacian.csv
# OCM尿1_薄い背景良_grid_laplacian.csv
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 23615 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 23615 missing from current font.
#   font.set_text(s, 0, flags=flags)
# OCM尿2_薄い背景悪_grid_laplacian.csv
# OUM血液培養553_背景良_grid_laplacian.csv
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 34880 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 28082 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 22521 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 39178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 34880 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 28082 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 22521 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 39178 missing from current font.
#   font.set_text(s, 0, flags=flags)
