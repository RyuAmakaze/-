# %%
import glob
import numpy as np
import matplotlib.pyplot as plt

files = glob.glob("all_lap/*.csv")
for file in files:  
    print(file)
    data_set = np.loadtxt(
    fname=file, #読み込むファイルのパスと名前
    dtype="float", #floatで読み込む
    delimiter=",", #csvなのでカンマで区切る
    encoding='utf-8',
    skiprows = 1
    )
    
    for data in data_set:
        plt.scatter(data[0], data[1])
    
    plt.title(file) #タイトル
    plt.xlabel("z") #x軸のラベル
    plt.ylabel("Max Grip_Laplacian Variance") #y軸のラベル
    plt.grid() #グリッド線を引く(引かなくてもいい別に)

    plt.show()
# Out:
# all_lap\OCM喀痰6_薄い背景悪_laplacian.csv
# all_lap\OPL血培51_薄い背景良_laplacian.csv
# all_lap\OPL血培67_適切背景_laplacian.csv
# all_lap\OUM801_8月20日16時16分27秒_laplacian.csv
# C:\Users\Yu Yamaoka\Anaconda3\envs\mrcnn\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 26376 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\envs\mrcnn\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\envs\mrcnn\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\envs\mrcnn\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20998 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yu Yamaoka\Anaconda3\envs\mrcnn\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 31186 missing from current font.
#   font.set_text(s, 0, flags=flags)
# all_lap\OUM801_血培8月20日15時53分54秒_laplacian.csv
# all_lap\OUM802_血培8月20日16時27分14秒_laplacian.csv
# all_lap\OUM802_血培8月20日16時31分23秒_laplacian.csv
# all_lap\OUM804_血培8月20日16時37分29秒_laplacian.csv
# all_lap\OUM811_血培8月20日15時46分28秒_laplacian.csv
# all_lap\OUM811血培_8月20日15時27分32秒_laplacian.csv
# all_lap\OUM血培812_8月20日14時26分0秒_laplacian.csv
